# %% [markdown]
# <a href="https://colab.research.google.com/github/xyluo25/grid2demand/blob/main/tutorial/SF_Example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !pip install grid2demand

# !git clone https://github.com/xyluo25/grid2demand

# %%
# !ls

# %%
import grid2demand as gd

if __name__ == "__main__":

    # Step 0: Specify input directory
    input_dir = r"grid2demand\datasets\demand_from_TAZ_centroid\SF"

    # Initialize a GRID2DEMAND object
    net = gd.GRID2DEMAND(input_dir=input_dir, verbose=False)

    # Step 1: Load node and poi data from input directory
    net.load_network()

    # Step 2: Generate zone dictionary from zone.csv file
    net.taz2zone()

    # Step 3: Run gravity model to generate agent-based demand
    net.run_gravity_model()

    # Step 4: Output demand, agent, zone, zone_od_dist_table, zone_od_dist_matrix files
    net.save_results_to_csv(node=False, poi=False, zone=False)
